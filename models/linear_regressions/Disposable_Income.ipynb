# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge

# %%
df = pd.read_csv("final_economic_data.csv")

df_total = df.copy()  

df_total = df_total[(df_total["Year"] >= 2010) & (df_total["Year"] <= 2022)] #no imports/exports

# %%
#Predicting Disposable Income

region_features = {
    1: [
        "I Accommodation and food service activities (TP)",
        "Gross value added (millions of euro), M Professional, scientific and technical activities (69-75)",
        "Property income, (incl. holding gains and losses), income",
        "Social benefits other than social transfers in kind, income",
    ],
    2: [
        "Employer's social security contributions, income",
        "O Public administration and defence; compulsory social security (TP)",
        "Mean of debt for debts charged on business activities and a source of income",
        "50 - 54 Rural (population)",
        "Gross value added (millions of euro), J Information and communication (58-63)",
    ],
    4: [
        "25 - 29 Rural (population)",
        "Gross value added (millions of euro), O Public administration and defence; compulsory social security (84)",
        "Matriculation examination (population)",
        "Property income, (incl. holding gains and losses), income",
    ],
    5: [
        "Unemployed (PT)",
        "Employer's social security contributions",
        "Academic degree, higher university level degree (population)",
        "Social benefits other than social transfers in kind, income",

    ],
    6: [
        "Mixed income, net",
        "30 - 34 Urban (population)",
        "Gross value added (millions of euro), M Professional, scientific and technical activities (69-75)",
        "P Education (TP)",
    ],
    7: [
        "30 - 34 Total (population)",
        "Mean of debt for debts charged on business activities and a source of income",
        "Property income, (incl. holding gains and losses), income",
        "25 - 29 Total (population)",
    ],
    8: [
        "Unemployed (PT)",
        "Total Rural (population)",
        "Property income, (incl. holding gains and losses), income",
        "Gross value added (millions of euro), R, S Other service activities (90-96)",
    ],
    9: [
        "Mean of debt for housing loan debts",
        "45 - 49 Rural (population)",
        "25 - 29 Total (population)",
        "25 - 29 Rural (population)",
    ],
    10: [
         "Property income, (incl. holding gains and losses), income",
        "G Wholesale and retail trade; repair of motor vehicles and motorcycles (TP)",
        "65 - 69 Rural (population)",
    ],
    11: [
        "Property income, (incl. holding gains and losses), income",
        "Gross value added (millions of euro), C Manufacturing (10-33)",
        "35 - 39 Total (population)",
    ],
    12: [
        "Gross value added (millions of euro), F Construction (41-43)",
        "Gross value added (millions of euro), M Professional, scientific and technical activities (69-75)",
        "C Manufacturing (TP)",
        "J Information and communication (TP)",
        "Property income, (incl. holding gains and losses), income",
    ],
    13: [
        "75- Total (population)",
        "Property income, (incl. holding gains and losses), income",
        "Total Rural (population)",
        "Median of debt for all debts",
    ],
    14: [
        "Inhabitants, total (PT)",
        "Gross value added (millions of euro), I Accommodation and food service activities (55-56)",
        "Gross value added (millions of euro), C Manufacturing (10-33)",
    ],
    15: [
        "N Administrative and support service activities (TP)",
        "30 - 34 Urban (population)",
        "Gross value added (millions of euro), N Administrative and support service activities (77-82)",
        "U Activities of extraterritorial organisations and bodies (TP)",
        "D Electricity, gas, steam and air conditioning supply (TP)",
    ],
    16: [
        "R Arts, entertainment and recreation (TP)",
        "0 - 19 Urban (population)",
        "Mixed income, net",
        "Basic level studies (population)",
        "GDP per capita (euro at current prices)",
    ],
    17: [
        "50 - 54 Urban (population)",
        "Gross value added (millions of euro), Q Human health and social work activities (86-88)",
        "0 - 19 Total (population)",
        "75- Urban (population)",
        "E Water supply; sewerage, waste management and remediation activities (TP)",
    ],
    18: [
        "Basic level studies (population)",
        "25 - 29 Urban (population)",
        "Property income, (incl. holding gains and losses), income",
        "30 - 34 Rural (population)",
    ],
    19: [
        "75- Total (population)",
        "Gross value added (millions of euro), I Accommodation and food service activities (55-56)",
        "Processing (TP)",
        "Mean of debt for housing loan debts",
    ],
    21: [
        "Income, property and other direct taxes excl. capital taxes, expenditure",
        "F Construction (TP)",
        "30 - 34 Total (population)",
        "Pensioners (PT)",
        "0 - 19 Rural (population)",
    ],
}

target_col = "Disposable income, net"

regions = df_total["Region"].unique()

# %%
for region in sorted(region_features.keys()):
    cols_features = region_features[region]

    print(f"\nRegion {region}")
    print("cols_features = [")
    for f in cols_features:
        print(f'    "{f}",')
    print("]")

    df_region = df_total[df_total["Region"] == region]
    
    # drop missing values
    df_model = df_region[["Year"] + cols_features + [target_col]].dropna()

    #drop empty and with not enough data regions
    if len(df_model) < 4:
        continue

    #features, target, year
    X = df_model[cols_features].copy()
    y = df_model[target_col]
    years = df_model["Year"]

    #adding year as predictor (new column)
    X["Year"] = years

    #train/test split by year
    X_train = X.loc[years <= 2019]
    y_train = y.loc[years <= 2019]
    X_test  = X.loc[years >= 2020]
    y_test  = y.loc[years >= 2020]
    
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    #Ridge Regression (regularized LR)
    model = Ridge(alpha=1.0)
    model.fit(X_train_scaled, y_train)

    #predictions
    y_pred_train = model.predict(X_train_scaled)
    y_pred_test  = model.predict(X_test_scaled)

    #predict on all data for plotting
    X_scaled_all = scaler.transform(X)
    y_pred_all = model.predict(X_scaled_all)
    
    results = pd.DataFrame({
        "Year": years,
        "Actual Disposable Income": y,
        "Predicted Disposable Income": y_pred_all
    }).sort_values("Year")
    
    print(f"Region {region} - Train R²:", model.score(X_train_scaled, y_train))
    print(f"Region {region} - Test  R²:", model.score(X_test_scaled, y_test))
    
    plt.figure(figsize=(10,6))
    plt.plot(results["Year"], results["Actual Disposable Income"], label="Actual Disposable Income", marker="o")
    plt.plot(results["Year"], results["Predicted Disposable Income"], label="Predicted Disposable Income", marker="x", linestyle="--")
    plt.axvline(2019.5, color="red", linestyle=":", label="Train/Test split")
    plt.xlabel("Year")
    plt.ylabel("Disposable Income (euro)")
    plt.title(f"Disposable Income: Actual vs Predicted (Region {region})")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Region 1
# cols_features = [
#     "I Accommodation and food service activities (TP)",
#     "Gross value added (millions of euro), M Professional, scientific and technical activities (69-75)",
#     "Property income, (incl. holding gains and losses), income",
#     "Social benefits other than social transfers in kind, income",
# ]
# Region 1 - Train R²: 0.9831583210718451
# Region 1 - Test  R²: 0.9911197059978056
# Region 2
# cols_features = [
#     "Employer's social security contributions, income",
#     "O Public administration and defence; compulsory social security (TP)",
#     "Mean of debt for debts charged on business activities and a source of income",
#     "50 - 54 Rural (population)",
#     "Gross value added (millions of euro), J Information and communication (58-63)",
# ]
# Region 2 - Train R²: 0.9876399973421041
# Region 2 - Test  R²: 0.9738130477033807
# Region 4
# cols_features = [
#     "25 - 29 Rural (population)",
#     "Gross value added (millions of euro), O Public administration and defence; compulsory social security (84)",
#     "Matriculation examination (population)",
#     "Property income, (incl. holding gains and losses), income",
# ]
# Region 4 - Train R²: 0.9755258934683052
# Region 4 - Test  R²: 0.9918880763274486
# Region 5
# cols_features = [
#     "Unemployed (PT)",
#     "Employer's social security contributions",
#     "Academic degree, higher university level degree (population)",
#     "Social benefits other than social transfers in kind, income",
# ]
# Region 5 - Train R²: 0.9779252034574368
# Region 5 - Test  R²: 0.9936935844789423
# Region 6
# cols_features = [
#     "Mixed income, net",
#     "30 - 34 Urban (population)",
#     "Gross value added (millions of euro), M Professional, scientific and technical activities (69-75)",
#     "P Education (TP)",
# ]
# Region 6 - Train R²: 0.9943061561740765
# Region 6 - Test  R²: 0.9946425990391194
# Region 7
# cols_features = [
#     "30 - 34 Total (population)",
#     "Mean of debt for debts charged on business activities and a source of income",
#     "Property income, (incl. holding gains and losses), income",
#     "25 - 29 Total (population)",
# ]
# Region 7 - Train R²: 0.9717685149755312
# Region 7 - Test  R²: 0.9865795949856047
# Region 8
# cols_features = [
#     "Unemployed (PT)",
#     "Total Rural (population)",
#     "Property income, (incl. holding gains and losses), income",
#     "Gross value added (millions of euro), R, S Other service activities (90-96)",
# ]
# Region 8 - Train R²: 0.9671464167663733
# Region 8 - Test  R²: 0.9757099421198135
# Region 9
# cols_features = [
#     "Mean of debt for housing loan debts",
#     "45 - 49 Rural (population)",
#     "25 - 29 Total (population)",
#     "25 - 29 Rural (population)",
# ]
# Region 9 - Train R²: 0.9479239312903428
# Region 9 - Test  R²: 0.9588577217040251
# Region 10
# cols_features = [
#     "Property income, (incl. holding gains and losses), income",
#     "G Wholesale and retail trade; repair of motor vehicles and motorcycles (TP)",
#     "65 - 69 Rural (population)",
# ]
# Region 10 - Train R²: 0.9506725082779602
# Region 10 - Test  R²: 0.966321112772408
# Region 11
# cols_features = [
#     "Property income, (incl. holding gains and losses), income",
#     "Gross value added (millions of euro), C Manufacturing (10-33)",
#     "35 - 39 Total (population)",
# ]
# Region 11 - Train R²: 0.9847025743122446
# Region 11 - Test  R²: 0.9807478919904308
# Region 12
# cols_features = [
#     "Gross value added (millions of euro), F Construction (41-43)",
#     "Gross value added (millions of euro), M Professional, scientific and technical activities (69-75)",
#     "C Manufacturing (TP)",
#     "J Information and communication (TP)",
#     "Property income, (incl. holding gains and losses), income",
# ]
# Region 12 - Train R²: 0.9892657766107787
# Region 12 - Test  R²: 0.9768673475695654
# Region 13
# cols_features = [
#     "75- Total (population)",
#     "Property income, (incl. holding gains and losses), income",
#     "Total Rural (population)",
#     "Median of debt for all debts",
# ]
# Region 13 - Train R²: 0.9857483550653947
# Region 13 - Test  R²: 0.9944234623733961
# Region 14
# cols_features = [
#     "Inhabitants, total (PT)",
#     "Gross value added (millions of euro), I Accommodation and food service activities (55-56)",
#     "Gross value added (millions of euro), C Manufacturing (10-33)",
# ]
# Region 14 - Train R²: 0.928432368922549
# Region 14 - Test  R²: 0.9472048468463812
# Region 15
# cols_features = [
#     "N Administrative and support service activities (TP)",
#     "30 - 34 Urban (population)",
#     "Gross value added (millions of euro), N Administrative and support service activities (77-82)",
#     "U Activities of extraterritorial organisations and bodies (TP)",
#     "D Electricity, gas, steam and air conditioning supply (TP)",
# ]
# Region 15 - Train R²: 0.9696516452983038
# Region 15 - Test  R²: 0.9816896375137109
# Region 16
# cols_features = [
#     "R Arts, entertainment and recreation (TP)",
#     "0 - 19 Urban (population)",
#     "Mixed income, net",
#     "Basic level studies (population)",
#     "GDP per capita (euro at current prices)",
# ]
# Region 16 - Train R²: 0.9726962715603114
# Region 16 - Test  R²: 0.9922304956581448
# Region 17
# cols_features = [
#     "50 - 54 Urban (population)",
#     "Gross value added (millions of euro), Q Human health and social work activities (86-88)",
#     "0 - 19 Total (population)",
#     "75- Urban (population)",
#     "E Water supply; sewerage, waste management and remediation activities (TP)",
# ]
# Region 17 - Train R²: 0.9828638023768942
# Region 17 - Test  R²: 0.9979540430905282
# Region 18
# cols_features = [
#     "Basic level studies (population)",
#     "25 - 29 Urban (population)",
#     "Property income, (incl. holding gains and losses), income",
#     "30 - 34 Rural (population)",
# ]
# Region 18 - Train R²: 0.9934424422597732
# Region 18 - Test  R²: 0.9872772924378663
# Region 19
# cols_features = [
#     "75- Total (population)",
#     "Gross value added (millions of euro), I Accommodation and food service activities (55-56)",
#     "Processing (TP)",
#     "Mean of debt for housing loan debts",
# ]
# Region 19 - Train R²: 0.9691447214328361
# Region 19 - Test  R²: 0.9525015774844409
# Region 21
# cols_features = [
#     "Income, property and other direct taxes excl. capital taxes, expenditure",
#     "F Construction (TP)",
#     "30 - 34 Total (population)",
#     "Pensioners (PT)",
#     "0 - 19 Rural (population)",
# ]
# Region 21 - Train R²: 0.9619004663053773
# Region 21 - Test  R²: 0.9785831633077073

# %%
summary = []

for region in sorted(region_features.keys()):
    cols_features = region_features[region]

    df_region = df_total[df_total["Region"] == region]

    df_model = df_region[["Year"] + cols_features + [target_col]].dropna()
    if len(df_model) < 4:
        continue

    X = df_model[cols_features].copy()
    y = df_model[target_col]
    years = df_model["Year"]
    X["Year"] = years

    X_train = X.loc[years <= 2019]
    y_train = y.loc[years <= 2019]
    X_test  = X.loc[years >= 2020]
    y_test  = y.loc[years >= 2020]

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    model = Ridge(alpha=1.0)
    model.fit(X_train_scaled, y_train)

    train_r2 = model.score(X_train_scaled, y_train)
    test_r2  = model.score(X_test_scaled, y_test)
    gap = abs(train_r2 - test_r2)

    summary.append({
        "Region": region,
        "Train R²": train_r2,
        "Test R²": test_r2,
        "Gap": gap
    })

summary_df = pd.DataFrame(summary)
print(summary_df)
# Out:
#     Region  Train R²   Test R²       Gap
# 0        1  0.983158  0.991120  0.007961
# 1        2  0.987640  0.973813  0.013827
# 2        4  0.975526  0.991888  0.016362
# 3        5  0.977925  0.993694  0.015768
# 4        6  0.994306  0.994643  0.000336
# 5        7  0.971769  0.986580  0.014811
# 6        8  0.967146  0.975710  0.008564
# 7        9  0.947924  0.958858  0.010934
# 8       10  0.950673  0.966321  0.015649
# 9       11  0.984703  0.980748  0.003955
# 10      12  0.989266  0.976867  0.012398
# 11      13  0.985748  0.994423  0.008675
# 12      14  0.928432  0.947205  0.018772
# 13      15  0.969652  0.981690  0.012038
# 14      16  0.972696  0.992230  0.019534
# 15      17  0.982864  0.997954  0.015090
# 16      18  0.993442  0.987277  0.006165
# 17      19  0.969145  0.952502  0.016643
# 18      21  0.961900  0.978583  0.016683
